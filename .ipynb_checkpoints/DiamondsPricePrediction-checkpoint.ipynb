# %% [markdown]
# task: to predict the price of diamond

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/My Drive/diamonds.csv'
df = pd.read_csv(file_path)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from sklearn import metrics

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# Data Preprocessing
#
# Data cleaning
#
# Identifying and removing outliers
#
# Encoding categorical variables

# %%
del df['Unnamed: 0']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (53794, 10)

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53794.0     0.797780     0.473390    0.2    0.40     0.70     1.04
# depth  53794.0    61.748080     1.429909   43.0   61.00    61.80    62.50
# table  53794.0    57.458109     2.233679   43.0   56.00    57.00    59.00
# price  53794.0  3933.065082  3988.114460  326.0  951.00  2401.00  5326.75
# x      53794.0     5.731214     1.120695    0.0    4.71     5.70     6.54
# y      53794.0     5.734653     1.141209    0.0    4.72     5.71     6.54
# z      53794.0     3.538714     0.705037    0.0    2.91     3.53     4.03
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %% [markdown]
# x, y and z is the length, width and depth of the diamond
#
# so, its not meant to be 0, i think being that means a diamond that isnt 3d.
#
# what are you then?, air, or paper
#
# so lets delete them

# %%
# Dropping rows with zero dimensions (x, y, or z)
df = df.drop(df[df["x"]==0].index)
df = df.drop(df[df["y"]==0].index)
df = df.drop(df[df["z"]==0].index)

# Printing the shape of the DataFrame after dropping rows
df.shape
# Out:
# (53775, 10)

# %%
df.describe().T
# Out:
#          count         mean          std     min     25%      50%      75%  \
# carat  53775.0     0.797536     0.473169    0.20    0.40     0.70     1.04
# depth  53775.0    61.748232     1.429639   43.00   61.00    61.80    62.50
# table  53775.0    57.457806     2.233257   43.00   56.00    57.00    59.00
# price  53775.0  3931.220288  3985.918716  326.00  951.00  2401.00  5324.00
# x      53775.0     5.731579     1.118611    3.73    4.71     5.70     6.54
# y      53775.0     5.734909     1.139451    3.68    4.72     5.71     6.54
# z      53775.0     3.539964     0.702017    1.07    2.91     3.53     4.03
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
# Define shades of blue blue_shades = ["#496D89", "#6D90A1", "#90B3B9", "#B3D6D1", "#D6E9E9"]
# Plot pairplot with shades of blue
ax = sns.pairplot(df, hue="cut")
# Show the plot
plt.show()

# %% [markdown]
# There are some features with datapoint that are far from the rest of the dataset which will affect the outcome of our regression model.(contains outliers)
#
#
# Most of the features are left skewed

# %%
# Plotting boxplots for depth, table, x, y, and z
variables = ['depth', 'table', 'x', 'y', 'z']

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Flatten the axes array
axes = axes.flatten()

# Iterate over variables and plot boxplots
for i, var in enumerate(variables):
    sns.boxplot(x=var, data=df, ax=axes[i])
    axes[i].set_title(f"Boxplot of '{var}'")
    axes[i].set_xlabel(var)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Plotting regression lines for depth, table, x, y, and z against price
variables = ['depth', 'table', 'x', 'y', 'z']

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Flatten the axes array
axes = axes.flatten()

# Iterate over variables and plot regression lines
for i, var in enumerate(variables):
    sns.regplot(x="price", y=var, data=df, fit_reg=True, scatter_kws={"color": "lightblue"}, line_kws={"color": "blue"}, ax=axes[i])
    axes[i].set_title(f"Regression Line on Price vs '{var}'")
    axes[i].set_xlabel('Price')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Dropping outliers from DataFrame df
df = df[(df["depth"] < 75) & (df["depth"] > 50)]
df = df[(df["table"] < 80) & (df["table"] > 40)]

df = df[df["y"] < 30]
df = df[(df["z"] < 30) & (df["z"] > 2)]

# Getting the shape of the DataFrame after dropping outliers
df.shape
# Out:
# (53763, 10)

# %%
# Plotting regression lines for depth, table, x, y, and z against price
variables = ['depth', 'table', 'x', 'y', 'z']
# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
# Flatten the axes array
axes = axes.flatten()

# Iterate over variables and plot regression lines
for i, var in enumerate(variables):
    sns.regplot(x="price", y=var, data=df, fit_reg=True, scatter_kws={"color": "lightblue"}, line_kws={"color": "blue"}, ax=axes[i])
    axes[i].set_title(f"Regression Line on Price vs '{var}'")
    axes[i].set_xlabel('Price')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# List of categorical variables
categorical_variables = ['cut', 'color', 'clarity']  # Adjust based on your dataset

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(20, 12))
# Flatten the axes array
axes = axes.flatten()

# Iterate over categorical variables and plot violin plots
for i, cat_var in enumerate(categorical_variables):
    sns.violinplot(x=cat_var, y='price', data=df, ax=axes[i])
    axes[i].set_title(f"Violin Plot of {cat_var.capitalize()} vs Price")
    axes[i].set_ylabel('Price')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Get list of categorical variables
s = (df.dtypes =="object")
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['cut', 'color', 'clarity']

# %%
# Make copy to avoid changing original data
label_df = df.copy()

# Apply label encoder to each column with categorical data
label_encoder = LabelEncoder()
for col in object_cols:
    label_df[col] = label_encoder.fit_transform(label_df[col])
label_df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75

# %%
corr_matrix = df.corr(numeric_only = True)
plt.figure(figsize=(15, 7))  # Set the size of the figure
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# "carat", "x", "y" and "z" show a high correlation to the target column, 'price'.

# %% [markdown]
# ## **MODEL BUILDING**

# %%
# Assigning the featurs as X and trarget as y
X= label_df.drop(["price"],axis =1)
y= label_df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25, random_state=7)

# %%
X_train
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 40768   0.50    2      6        5   62.0   56.0  5.08  5.12  3.16
# 42477   0.50    4      0        2   61.6   59.0  5.12  5.14  3.16
# 31799   0.42    2      5        4   62.0   55.0  4.83  4.85  3.00
# 28523   0.41    2      6        4   62.2   54.5  4.75  4.76  2.96
# 7083    0.85    2      3        4   61.6   54.0  6.08  6.12  3.76
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 919     0.72    0      2        4   56.9   69.0  5.93  5.77  3.33
# 53636   0.30    2      0        2   61.6   57.0  4.28  4.32  2.65
# 38608   0.39    4      0        5   59.5   57.0  4.79  4.82  2.86
# 10775   1.23    3      6        5   62.7   58.0  6.81  6.77  4.26
# 49862   0.62    2      3        4   62.0   56.0  5.45  5.49  3.39
#
# [40322 rows x 9 columns]

# %%
def model_performance(model, predictors, target):
    """
    Function to compute different metrics to check regression model performance.

    model: Regressor model
    predictors: Independent variables
    target: Dependent variable
    """

    # Predict using the independent variables
    pred = model.predict(predictors)

    # Compute regression metrics
    mae = mean_absolute_error(target, pred)  # Mean Absolute Error
    mse = mean_squared_error(target, pred)  # Mean Squared Error
    rmse = mean_squared_error(target, pred, squared=False)  # Root Mean Squared Error
    r2 = r2_score(target, pred)  # R-squared score

    # Compute Mean Absolute Percentage Error (MAPE)
    mape = (100 * (abs(target - pred) / abs(target))).mean()

    # Create a DataFrame of metrics
    df_perf = pd.DataFrame({
        "MAE": [mae],
        "MSE": [mse],
        "RMSE": [rmse],
        "R-squared": [r2],
        "MAPE": [mape]
    })

    return df_perf

# %%
# Create and train the model
LRmodel = LinearRegression()
LRmodel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
LRtrain = model_performance(LRmodel, X_train, y_train)
LRtrain
# Out:
#           MAE           MSE       RMSE  R-squared      MAPE
# 0  849.464031  1.775257e+06  1332.3878   0.888688  37.54294

# %%
LRtest = model_performance(LRmodel, X_test, y_test)
LRtest
# Out:
#          MAE           MSE         RMSE  R-squared       MAPE
# 0  851.96555  1.857556e+06  1362.921968   0.881681  37.898496

# %%
from sklearn.model_selection import GridSearchCV

# Define the model
linear_regression = LinearRegression()

# Define hyperparameters to tune
parameters = {'fit_intercept': [True, False]}

# Perform grid search cross-validation
grid_search = GridSearchCV(linear_regression, parameters, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params_lr = grid_search.best_params_
print("Best Hyperparameters for Linear Regression:", best_params_lr)

# Train the model with the best hyperparameters
best_lr_model = LinearRegression(**best_params_lr)
best_lr_model.fit(X_train, y_train)
# Out:
# Best Hyperparameters for Linear Regression: {'fit_intercept': False}
# LinearRegression(fit_intercept=False)

# %%
tuned_LRtrain = model_performance(best_lr_model, X_train, y_train)
tuned_LRtrain
# Out:
#           MAE           MSE         RMSE  R-squared      MAPE
# 0  849.353892  1.775459e+06  1332.463539   0.888675  37.52135

# %%
tuned_LRtest = model_performance(best_lr_model, X_test, y_test)
tuned_LRtest
# Out:
#          MAE           MSE         RMSE  R-squared       MAPE
# 0  851.75781  1.855727e+06  1362.250614   0.881797  37.865722

# %%
# Initialize the XGBoost regressor model
xgb_regressor = XGBRegressor()

# Training the XGBoost regressor model
xgb_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgbtrain = model_performance(xgb_regressor, X_train, y_train)
xgbtrain
# Out:
#           MAE            MSE        RMSE  R-squared      MAPE
# 0  222.451507  154778.153516  393.418547   0.990295  6.472658

# %%
xgbtest = model_performance(xgb_regressor, X_test, y_test)
xgbtest
# Out:
#          MAE            MSE        RMSE  R-squared      MAPE
# 0  283.18287  303671.004809  551.063522   0.980657  7.280299

# %%
# Define the model
xgb_regressor = XGBRegressor()

# Define hyperparameters to tune
parameters = {'n_estimators': [50, 100, 150],
              'learning_rate': [0.01, 0.1, 0.3],
              'max_depth': [3, 5, 7]}

# Perform grid search cross-validation
grid_search = GridSearchCV(xgb_regressor, parameters, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params_xgb = grid_search.best_params_
print("Best Hyperparameters for XGBoost Regressor:", best_params_xgb)

# Train the model with the best hyperparameters
best_xgb_model = XGBRegressor(**best_params_xgb)
best_xgb_model.fit(X_train, y_train)
# Out:
# Best Hyperparameters for XGBoost Regressor: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
tuned_xgbtrain = model_performance(best_xgb_model, X_train, y_train)
tuned_xgbtrain
# Out:
#           MAE            MSE        RMSE  R-squared      MAPE
# 0  231.980788  179690.460591  423.899116   0.988733  6.749336

# %%
tuned_xgbtest = model_performance(best_xgb_model, X_test, y_test)
tuned_xgbtest
# Out:
#           MAE            MSE        RMSE  R-squared      MAPE
# 0  272.193453  278699.000023  527.919501   0.982248  7.335326
